# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
import sys
# !{sys.executable} -m pip install geocoder
# Out:
# Requirement already satisfied: geocoder in /home/jupyterlab/conda/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: click in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: ratelim in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: future in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: six in /home/jupyterlab/conda/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (2018.11.29)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/jupyterlab/conda/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.2)

# %%
import pandas as pd
import wikipedia as wp
 
#Get the html source
html = wp.page("List of postal codes of Canada: M").html().encode("UTF-8")
df = pd.read_html(html)[0]
df.to_csv('toronto.csv',header=0,index=False)
print (df)
# Out:
#     Postcode           Borough  \
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York
# 3        M4A        North York
# 4        M5A  Downtown Toronto
# 5        M5A  Downtown Toronto
# 6        M6A        North York
# 7        M6A        North York
# 8        M7A      Queen's Park
# 9        M8A      Not assigned
# 10       M9A         Etobicoke
# 11       M1B       Scarborough
# 12       M1B       Scarborough
# 13       M2B      Not assigned
# 14       M3B        North York
# 15       M4B         East York
# 16       M4B         East York
# 17       M5B  Downtown Toronto
# 18       M5B  Downtown Toronto
# 19       M6B        North York
# 20       M7B      Not assigned
# 21       M8B      Not assigned
# 22       M9B         Etobicoke
# 23       M9B         Etobicoke
# 24       M9B         Etobicoke
# 25       M9B         Etobicoke
# 26       M9B         Etobicoke
# 27       M1C       Scarborough
# 28       M1C       Scarborough
# 29       M1C       Scarborough
# 30       M2C      Not assigned
# 31       M3C        North York
# 32       M3C        North York
# 33       M4C         East York
# 34       M5C  Downtown Toronto
# 35       M6C              York
# 36       M7C      Not assigned
# 37       M8C      Not assigned
# 38       M9C         Etobicoke
# 39       M9C         Etobicoke
# 40       M9C         Etobicoke
# 41       M9C         Etobicoke
# 42       M1E       Scarborough
# 43       M1E       Scarborough
# 44       M1E       Scarborough
# 45       M2E      Not assigned
# 46       M3E      Not assigned
# 47       M4E      East Toronto
# 48       M5E  Downtown Toronto
# 49       M6E              York
# 50       M7E      Not assigned
# 51       M8E      Not assigned
# 52       M9E      Not assigned
# 53       M1G       Scarborough
# 54       M2G      Not assigned
# 55       M3G      Not assigned
# 56       M4G         East York
# 57       M5G  Downtown Toronto
# 58       M6G  Downtown Toronto
# 59       M7G      Not assigned
# 60       M8G      Not assigned
# 61       M9G      Not assigned
# 62       M1H       Scarborough
# 63       M2H        North York
# 64       M3H        North York
# 65       M3H        North York
# 66       M3H        North York
# 67       M4H         East York
# 68       M5H  Downtown Toronto
# 69       M5H  Downtown Toronto
# 70       M5H  Downtown Toronto
# 71       M6H      West Toronto
# 72       M6H      West Toronto
# 73       M7H      Not assigned
# 74       M8H      Not assigned
# 75       M9H      Not assigned
# 76       M1J       Scarborough
# 77       M2J        North York
# 78       M2J        North York
# 79       M2J        North York
# 80       M3J        North York
# 81       M3J        North York
# 82       M4J         East York
# 83       M5J  Downtown Toronto
# 84       M5J  Downtown Toronto
# 85       M5J  Downtown Toronto
# 86       M6J      West Toronto
# 87       M6J      West Toronto
# 88       M7J      Not assigned
# 89       M8J      Not assigned
# 90       M9J      Not assigned
# 91       M1K       Scarborough
# 92       M1K       Scarborough
# 93       M1K       Scarborough
# 94       M2K        North York
# 95       M3K        North York
# 96       M3K        North York
# 97       M4K      East Toronto
# 98       M4K      East Toronto
# 99       M5K  Downtown Toronto
# 100      M5K  Downtown Toronto
# 101      M6K      West Toronto
# 102      M6K      West Toronto
# 103      M6K      West Toronto
# 104      M7K      Not assigned
# 105      M8K      Not assigned
# 106      M9K      Not assigned
# 107      M1L       Scarborough
# 108      M1L       Scarborough
# 109      M1L       Scarborough
# 110      M2L        North York
# 111      M2L        North York
# 112      M3L        North York
# 113      M4L      East Toronto
# 114      M4L      East Toronto
# 115      M5L  Downtown Toronto
# 116      M5L  Downtown Toronto
# 117      M6L        North York
# 118      M6L        North York
# 119      M6L        North York
# 120      M7L      Not assigned
# 121      M8L      Not assigned
# 122      M9L        North York
# 123      M1M       Scarborough
# 124      M1M       Scarborough
# 125      M1M       Scarborough
# 126      M2M        North York
# 127      M2M        North York
# 128      M3M        North York
# 129      M4M      East Toronto
# 130      M5M        North York
# 131      M5M        North York
# 132      M6M              York
# 133      M6M              York
# 134      M6M              York
# 135      M6M              York
# 136      M7M      Not assigned
# 137      M8M      Not assigned
# 138      M9M        North York
# 139      M9M        North York
# 140      M1N       Scarborough
# 141      M1N       Scarborough
# 142      M2N        North York
# 143      M3N        North York
# 144      M4N   Central Toronto
# 145      M5N   Central Toronto
# 146      M6N              York
# 147      M6N              York
# 148      M7N      Not assigned
# 149      M8N      Not assigned
# 150      M9N              York
# 151      M1P       Scarborough
# 152      M1P       Scarborough
# 153      M1P       Scarborough
# 154      M2P        North York
# 155      M3P      Not assigned
# 156      M4P   Central Toronto
# 157      M5P   Central Toronto
# 158      M5P   Central Toronto
# 159      M6P      West Toronto
# 160      M6P      West Toronto
# 161      M7P      Not assigned
# 162      M8P      Not assigned
# 163      M9P         Etobicoke
# 164      M1R       Scarborough
# 165      M1R       Scarborough
# 166      M2R        North York
# 167      M3R      Not assigned
# 168      M4R   Central Toronto
# 169      M5R   Central Toronto
# 170      M5R   Central Toronto
# 171      M5R   Central Toronto
# 172      M6R      West Toronto
# 173      M6R      West Toronto
# 174      M7R       Mississauga
# 175      M8R      Not assigned
# 176      M9R         Etobicoke
# 177      M9R         Etobicoke
# 178      M9R         Etobicoke
# 179      M9R         Etobicoke
# 180      M1S       Scarborough
# 181      M2S      Not assigned
# 182      M3S      Not assigned
# 183      M4S   Central Toronto
# 184      M5S  Downtown Toronto
# 185      M5S  Downtown Toronto
# 186      M6S      West Toronto
# 187      M6S      West Toronto
# 188      M7S      Not assigned
# 189      M8S      Not assigned
# 190      M9S      Not assigned
# 191      M1T       Scarborough
# 192      M1T       Scarborough
# 193      M1T       Scarborough
# 194      M2T      Not assigned
# 195      M3T      Not assigned
# 196      M4T   Central Toronto
# 197      M4T   Central Toronto
# 198      M5T  Downtown Toronto
# 199      M5T  Downtown Toronto
# 200      M5T  Downtown Toronto
# 201      M6T      Not assigned
# 202      M7T      Not assigned
# 203      M8T      Not assigned
# 204      M9T      Not assigned
# 205      M1V       Scarborough
# 206      M1V       Scarborough
# 207      M1V       Scarborough
# 208      M1V       Scarborough
# 209      M2V      Not assigned
# 210      M3V      Not assigned
# 211      M4V   Central Toronto
# 212      M4V   Central Toronto
# 213      M4V   Central Toronto
# 214      M4V   Central Toronto
# 215      M4V   Central Toronto
# 216      M5V  Downtown Toronto
# 217      M5V  Downtown Toronto
# 218      M5V  Downtown Toronto
# 219      M5V  Downtown Toronto
# 220      M5V  Downtown Toronto
# 221      M5V  Downtown Toronto
# 222      M5V  Downtown Toronto
# 223      M6V      Not assigned
# 224      M7V      Not assigned
# 225      M8V         Etobicoke
# 226      M8V         Etobicoke
# 227      M8V         Etobicoke
# 228      M9V         Etobicoke
# 229      M9V         Etobicoke
# 230      M9V         Etobicoke
# 231      M9V         Etobicoke
# 232      M9V         Etobicoke
# 233      M9V         Etobicoke
# 234      M9V         Etobicoke
# 235      M9V         Etobicoke
# 236      M1W       Scarborough
# 237      M1W       Scarborough
# 238      M2W      Not assigned
# 239      M3W      Not assigned
# 240      M4W  Downtown Toronto
# 241      M5W  Downtown Toronto
# 242      M6W      Not assigned
# 243      M7W      Not assigned
# 244      M8W         Etobicoke
# 245      M8W         Etobicoke
# 246      M9W         Etobicoke
# 247      M1X       Scarborough
# 248      M2X      Not assigned
# 249      M3X      Not assigned
# 250      M4X  Downtown Toronto
# 251      M4X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 253      M5X  Downtown Toronto
# 254      M6X      Not assigned
# 255      M7X      Not assigned
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 258      M8X         Etobicoke
# 259      M9X      Not assigned
# 260      M1Y      Not assigned
# 261      M2Y      Not assigned
# 262      M3Y      Not assigned
# 263      M4Y  Downtown Toronto
# 264      M5Y      Not assigned
# 265      M6Y      Not assigned
# 266      M7Y      East Toronto
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 274      M8Y         Etobicoke
# 275      M9Y      Not assigned
# 276      M1Z      Not assigned
# 277      M2Z      Not assigned
# 278      M3Z      Not assigned
# 279      M4Z      Not assigned
# 280      M5Z      Not assigned
# 281      M6Z      Not assigned
# 282      M7Z      Not assigned
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
# 287      M8Z         Etobicoke
# 288      M9Z      Not assigned
#
#                                          Neighbourhood
# 0                                         Not assigned
# 1                                         Not assigned
# 2                                            Parkwoods
# 3                                     Victoria Village
# 4                                         Harbourfront
# 5                                          Regent Park
# 6                                     Lawrence Heights
# 7                                       Lawrence Manor
# 8                                         Not assigned
# 9                                         Not assigned
# 10                                    Islington Avenue
# 11                                               Rouge
# 12                                             Malvern
# 13                                        Not assigned
# 14                                     Don Mills North
# 15                                    Woodbine Gardens
# 16                                       Parkview Hill
# 17                                             Ryerson
# 18                                     Garden District
# 19                                           Glencairn
# 20                                        Not assigned
# 21                                        Not assigned
# 22                                          Cloverdale
# 23                                           Islington
# 24                                        Martin Grove
# 25                                    Princess Gardens
# 26                                     West Deane Park
# 27                                      Highland Creek
# 28                                          Rouge Hill
# 29                                          Port Union
# 30                                        Not assigned
# 31                                     Flemingdon Park
# 32                                     Don Mills South
# 33                                    Woodbine Heights
# 34                                      St. James Town
# 35                                  Humewood-Cedarvale
# 36                                        Not assigned
# 37                                        Not assigned
# 38                                   Bloordale Gardens
# 39                                            Eringate
# 40                                       Markland Wood
# 41                                   Old Burnhamthorpe
# 42                                           Guildwood
# 43                                         Morningside
# 44                                           West Hill
# 45                                        Not assigned
# 46                                        Not assigned
# 47                                         The Beaches
# 48                                         Berczy Park
# 49                                 Caledonia-Fairbanks
# 50                                        Not assigned
# 51                                        Not assigned
# 52                                        Not assigned
# 53                                              Woburn
# 54                                        Not assigned
# 55                                        Not assigned
# 56                                             Leaside
# 57                                  Central Bay Street
# 58                                            Christie
# 59                                        Not assigned
# 60                                        Not assigned
# 61                                        Not assigned
# 62                                           Cedarbrae
# 63                                   Hillcrest Village
# 64                                      Bathurst Manor
# 65                                     Downsview North
# 66                                      Wilson Heights
# 67                                    Thorncliffe Park
# 68                                            Adelaide
# 69                                                King
# 70                                            Richmond
# 71                                  Dovercourt Village
# 72                                            Dufferin
# 73                                        Not assigned
# 74                                        Not assigned
# 75                                        Not assigned
# 76                                 Scarborough Village
# 77                                            Fairview
# 78                                          Henry Farm
# 79                                              Oriole
# 80                                      Northwood Park
# 81                                     York University
# 82                                        East Toronto
# 83                                   Harbourfront East
# 84                                     Toronto Islands
# 85                                       Union Station
# 86                                     Little Portugal
# 87                                             Trinity
# 88                                        Not assigned
# 89                                        Not assigned
# 90                                        Not assigned
# 91                                East Birchmount Park
# 92                                             Ionview
# 93                                        Kennedy Park
# 94                                     Bayview Village
# 95                                         CFB Toronto
# 96                                      Downsview East
# 97                                   The Danforth West
# 98                                           Riverdale
# 99                                     Design Exchange
# 100                            Toronto Dominion Centre
# 101                                           Brockton
# 102                                   Exhibition Place
# 103                                   Parkdale Village
# 104                                       Not assigned
# 105                                       Not assigned
# 106                                       Not assigned
# 107                                           Clairlea
# 108                                        Golden Mile
# 109                                           Oakridge
# 110                                       Silver Hills
# 111                                         York Mills
# 112                                     Downsview West
# 113                                   The Beaches West
# 114                                       India Bazaar
# 115                                     Commerce Court
# 116                                     Victoria Hotel
# 117                                    Maple Leaf Park
# 118                                         North Park
# 119                                        Upwood Park
# 120                                       Not assigned
# 121                                       Not assigned
# 122                                      Humber Summit
# 123                                         Cliffcrest
# 124                                          Cliffside
# 125                           Scarborough Village West
# 126                                        Newtonbrook
# 127                                         Willowdale
# 128                                  Downsview Central
# 129                                    Studio District
# 130                                       Bedford Park
# 131                                Lawrence Manor East
# 132                                            Del Ray
# 133                                         Keelesdale
# 134                                       Mount Dennis
# 135                                        Silverthorn
# 136                                       Not assigned
# 137                                       Not assigned
# 138                                              Emery
# 139                                          Humberlea
# 140                                        Birch Cliff
# 141                                     Cliffside West
# 142                                   Willowdale South
# 143                                Downsview Northwest
# 144                                      Lawrence Park
# 145                                           Roselawn
# 146                                 The Junction North
# 147                                          Runnymede
# 148                                       Not assigned
# 149                                       Not assigned
# 150                                             Weston
# 151                                        Dorset Park
# 152                            Scarborough Town Centre
# 153                                    Wexford Heights
# 154                                    York Mills West
# 155                                       Not assigned
# 156                                   Davisville North
# 157                                  Forest Hill North
# 158                                   Forest Hill West
# 159                                          High Park
# 160                                 The Junction South
# 161                                       Not assigned
# 162                                       Not assigned
# 163                                          Westmount
# 164                                           Maryvale
# 165                                            Wexford
# 166                                    Willowdale West
# 167                                       Not assigned
# 168                                 North Toronto West
# 169                                          The Annex
# 170                                      North Midtown
# 171                                          Yorkville
# 172                                           Parkdale
# 173                                       Roncesvalles
# 174              Canada Post Gateway Processing Centre
# 175                                       Not assigned
# 176                                  Kingsview Village
# 177                               Martin Grove Gardens
# 178                                   Richview Gardens
# 179                                       St. Phillips
# 180                                          Agincourt
# 181                                       Not assigned
# 182                                       Not assigned
# 183                                         Davisville
# 184                                            Harbord
# 185                              University of Toronto
# 186                                          Runnymede
# 187                                            Swansea
# 188                                       Not assigned
# 189                                       Not assigned
# 190                                       Not assigned
# 191                                     Clarks Corners
# 192                                           Sullivan
# 193                                      Tam O'Shanter
# 194                                       Not assigned
# 195                                       Not assigned
# 196                                         Moore Park
# 197                                    Summerhill East
# 198                                          Chinatown
# 199                                        Grange Park
# 200                                  Kensington Market
# 201                                       Not assigned
# 202                                       Not assigned
# 203                                       Not assigned
# 204                                       Not assigned
# 205                                    Agincourt North
# 206                                    L'Amoreaux East
# 207                                           Milliken
# 208                                       Steeles East
# 209                                       Not assigned
# 210                                       Not assigned
# 211                                          Deer Park
# 212                                     Forest Hill SE
# 213                                          Rathnelly
# 214                                         South Hill
# 215                                    Summerhill West
# 216                                           CN Tower
# 217                                      Bathurst Quay
# 218                                     Island airport
# 219                                  Harbourfront West
# 220                                   King and Spadina
# 221                                      Railway Lands
# 222                                      South Niagara
# 223                                       Not assigned
# 224                                       Not assigned
# 225                                  Humber Bay Shores
# 226                                       Mimico South
# 227                                        New Toronto
# 228                                     Albion Gardens
# 229                                   Beaumond Heights
# 230                                         Humbergate
# 231                                          Jamestown
# 232                                        Mount Olive
# 233                                        Silverstone
# 234                                      South Steeles
# 235                                        Thistletown
# 236                                    L'Amoreaux West
# 237                                       Steeles West
# 238                                       Not assigned
# 239                                       Not assigned
# 240                                           Rosedale
# 241                    Stn A PO Boxes 25 The Esplanade
# 242                                       Not assigned
# 243                                       Not assigned
# 244                                          Alderwood
# 245                                        Long Branch
# 246                                          Northwest
# 247                                        Upper Rouge
# 248                                       Not assigned
# 249                                       Not assigned
# 250                                        Cabbagetown
# 251                                     St. James Town
# 252                               First Canadian Place
# 253                                   Underground city
# 254                                       Not assigned
# 255                                       Not assigned
# 256                                       The Kingsway
# 257                                    Montgomery Road
# 258                                     Old Mill North
# 259                                       Not assigned
# 260                                       Not assigned
# 261                                       Not assigned
# 262                                       Not assigned
# 263                               Church and Wellesley
# 264                                       Not assigned
# 265                                       Not assigned
# 266  Business Reply Mail Processing Centre 969 Eastern
# 267                                         Humber Bay
# 268                                   King's Mill Park
# 269                           Kingsway Park South East
# 270                                          Mimico NE
# 271                                     Old Mill South
# 272                                 The Queensway East
# 273                              Royal York South East
# 274                                           Sunnylea
# 275                                       Not assigned
# 276                                       Not assigned
# 277                                       Not assigned
# 278                                       Not assigned
# 279                                       Not assigned
# 280                                       Not assigned
# 281                                       Not assigned
# 282                                       Not assigned
# 283                           Kingsway Park South West
# 284                                          Mimico NW
# 285                                 The Queensway West
# 286                              Royal York South West
# 287                                     South of Bloor
# 288                                       Not assigned

# %%
df = pd.read_csv('toronto.csv')

# %%
df.head()
# Out:
#    M1A      Not assigned    Not assigned.1
# 0  M2A      Not assigned      Not assigned
# 1  M3A        North York         Parkwoods
# 2  M4A        North York  Victoria Village
# 3  M5A  Downtown Toronto      Harbourfront
# 4  M5A  Downtown Toronto       Regent Park

# %%
df.columns = ['Postcode', 'Borough','Neighbourhood']

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M2A      Not assigned      Not assigned
# 1      M3A        North York         Parkwoods
# 2      M4A        North York  Victoria Village
# 3      M5A  Downtown Toronto      Harbourfront
# 4      M5A  Downtown Toronto       Regent Park

# %%
df['Borough'].replace('Not assigned', np.nan, inplace=True)
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 0      M2A               NaN      Not assigned
# 1      M3A        North York         Parkwoods
# 2      M4A        North York  Victoria Village
# 3      M5A  Downtown Toronto      Harbourfront
# 4      M5A  Downtown Toronto       Regent Park

# %%
df.dropna(subset=['Borough'], inplace=True)

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 1      M3A        North York         Parkwoods
# 2      M4A        North York  Victoria Village
# 3      M5A  Downtown Toronto      Harbourfront
# 4      M5A  Downtown Toronto       Regent Park
# 5      M6A        North York  Lawrence Heights

# %%
df['Neighbourhood'].replace('Not assigned', df['Borough'], inplace=True)

# %%
df.head()
# Out:
#   Postcode           Borough     Neighbourhood
# 1      M3A        North York         Parkwoods
# 2      M4A        North York  Victoria Village
# 3      M5A  Downtown Toronto      Harbourfront
# 4      M5A  Downtown Toronto       Regent Park
# 5      M6A        North York  Lawrence Heights

# %%
df.shape

# %%
df['Latitude'] = 0

# %%
df['Longitude'] = 1

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests

wikipedia_link='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
raw_wikipedia_page= requests.get(wikipedia_link).text

soup = BeautifulSoup(raw_wikipedia_page,'lxml')
#print(soup.prettify())

# %%
table = soup.find('table')

Postcode      = []
Borough       = []
Neighbourhood = []

# print(table)

for tr_cell in table.find_all('tr'):
    
    counter = 1
    Postcode_var      = -1
    Borough_var       = -1
    Neighbourhood_var = -1
    
    for td_cell in tr_cell.find_all('td'):
        if counter == 1: 
            Postcode_var = td_cell.text
        if counter == 2: 
            Borough_var = td_cell.text
            tag_a_Borough = td_cell.find('a')
            
        if counter == 3: 
            Neighbourhood_var = str(td_cell.text).strip()
            tag_a_Neighbourhood = td_cell.find('a')
            
        counter +=1
        
    if (Postcode_var == 'Not assigned' or Borough_var == 'Not assigned' or Neighbourhood_var == 'Not assigned'): 
        continue
    try:
        if ((tag_a_Borough is None) or (tag_a_Neighbourhood is None)):
            continue
    except:
        pass
    if(Postcode_var == -1 or Borough_var == -1 or Neighbourhood_var == -1):
        continue
        
    Postcode.append(Postcode_var)
    Borough.append(Borough_var)
    Neighbourhood.append(Neighbourhood_var)

# %%
unique_p = set(Postcode)
# print('num of unique Postal codes:', len(unique_p))
Postcode_u      = []
Borough_u       = []
Neighbourhood_u = []


for postcode_unique_element in unique_p:
    p_var = ''; b_var = ''; n_var = ''; 
    for postcode_idx, postcode_element in enumerate(Postcode):
        if postcode_unique_element == postcode_element:
            p_var = postcode_element;
            b_var = Borough[postcode_idx]
            if n_var == '': 
                n_var = Neighbourhood[postcode_idx]
            else:
                n_var = n_var + ', ' + Neighbourhood[postcode_idx]
    Postcode_u.append(p_var)
    Borough_u.append(b_var)
    Neighbourhood_u.append(n_var)

# %%
import geocoder
Postcode_u = df['Postcode']
latitude = []
longitude = []
for elem in Postcode_u:
# initialize your variable to None
    lat_lng_coords = None

# loop until you get the coordinates
    while (lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(elem))
        lat_lng_coords = g.latlng
        # print(lat_lng_coords)

    latitude.append(lat_lng_coords[0])
    longitude.append(lat_lng_coords[1])
    print(elem, 'is RECEIVED.')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-3f5a2a6f1419> in <module>
#       9 # loop until you get the coordinates
#      10     while (lat_lng_coords is None):
# ---> 11         g = geocoder.google('{}, Toronto, Ontario'.format(elem))
#      12         lat_lng_coords = g.latlng
#      13         # print(lat_lng_coords)
#
# ~/conda/lib/python3.6/site-packages/geocoder/api.py in google(location, **kwargs)
#     230         > elevation
#     231     """
# --> 232     return get(location, provider='google', **kwargs)
#     233
#     234
#
# ~/conda/lib/python3.6/site-packages/geocoder/api.py in get(location, **kwargs)
#     196         if method not in options[provider]:
#     197             raise ValueError("Invalid method")
# --> 198     return options[provider][method](location, **kwargs)
#     199
#     200
#
# ~/conda/lib/python3.6/site-packages/geocoder/base.py in __init__(self, location, **kwargs)
#     408
#     409         # query and parse results
# --> 410         self._initialize()
#     411
#     412     def __getitem__(self, key):
#
# ~/conda/lib/python3.6/site-packages/geocoder/base.py in _initialize(self)
#     455     def _initialize(self):
#     456         # query URL and get valid JSON (also stored in self.json)
# --> 457         json_response = self._connect()
#     458
#     459         # catch errors
#
# ~/conda/lib/python3.6/site-packages/geocoder/base.py in _connect(self)
#     482                 headers=self.headers,
#     483                 timeout=self.timeout,
# --> 484                 proxies=self.proxies
#     485             )
#     486
#
# ~/conda/lib/python3.6/site-packages/geocoder/google.py in rate_limited_get(self, *args, **kwargs)
#     267             return self.rate_limited_get_for_work(*args, **kwargs)
#     268         else:
# --> 269             return self.rate_limited_get_for_dev(*args, **kwargs)
#     270
#     271     @ratelim.greedy(2500, 60 * 60 * 24)
#
# </home/jupyterlab/conda/lib/python3.6/site-packages/decorator.py:decorator-gen-127> in rate_limited_get_for_dev(self, *args, **kwargs)
#
# ~/conda/lib/python3.6/site-packages/ratelim/__init__.py in wrapped_f(self, f, *args, **kwargs)
#      31             time_delta = int(time_delta.total_seconds()) + 1
#      32             if time_delta <= self.__time_interval:
# ---> 33                 time.sleep(self.__time_interval - time_delta + 1)
#      34                 self.__numcalls = 0
#      35                 self.__last_reset = datetime.datetime.now()
#
# KeyboardInterrupt:

# %%
def get_geocoder(postal_code_from_df):
     # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code_from_df))
        lat_lng_coords = g.latlng
    latitude = lat_lng_coords[0]
    longitude = lat_lng_coords[1]
    return latitude,longitude



for i in range(0,len(df)):
    df['Latitude'][i],df['Longitude'][i]=get_geocoder(df.iloc[i]['Postcode'])

# %%
df
# Out:
#     Postcode           Borough  \
# 1        M3A        North York
# 2        M4A        North York
# 3        M5A  Downtown Toronto
# 4        M5A  Downtown Toronto
# 5        M6A        North York
# 6        
# 167      M4R   Central Toronto
# 168      M5R   Central Toronto
# 169      M5R   Central Toronto
# 170      M5R   Central Toronto
# 171      M6R      West Toronto
# 172      M6R      West Toronto
# 173      M7R       Mississauga
# 175      M9R         Etobicoke
# 176      M9R         Etobicoke
# 177      M9R         Etobicoke
# 178      M9R         Etobicoke
# 179      M1S       Scarborough
# 182      M4S   Central Toronto
# 183      M5S  Downtown Toronto
# 184      M5S  Downtown Toronto
# 185      M6S      West Toronto
# 186      M6S      West Toronto
# 190      M1T       Scarborough
# 191      M1T       Scarborough
# 192      M1T       Scarborough
# 195      M4T   Central Toronto
# 196      M4T   Central Toronto
# 197      M5T  Downtown Toronto
# 198      M5T  Downtown Toronto
# 199      M5T  Downtown Toronto
# 204      M1V       Scarborough
# 205      M1V       Scarborough
# 206      M1V       Scarborough
# 207      M1V       Scarborough
# 210      M4V   Central Toronto
# 211      M4V   Central Toronto
# 212      M4V   Central Toronto
# 213      M4V   Central Toronto
# 214      M4V   Central Toronto
# 215      M5V  Downtown Toronto
# 216      M5V  Downtown Toronto
# 217      M5V  Downtown Toronto
# 218      M5V  Downtown Toronto
# 219      M5V  Downtown Toronto
# 220      M5V  Downtown Toronto
# 221      M5V  Downtown Toronto
# 224      M8V         Etobicoke
# 225      M8V         Etobicoke
# 226      M8V         Etobicoke
# 227      M9V         Etobicoke
# 228      M9V         Etobicoke
# 229      M9V         Etobicoke
# 230      M9V         Etobicoke
# 231      M9V         Etobicoke
# 232      M9V         Etobicoke
# 233      M9V         Etobicoke
# 234      M9V         Etobicoke
# 235      M1W       Scarborough
# 236      M1W       Scarborough
# 239      M4W  Downtown Toronto
# 240      M5W  Downtown Toronto
# 243      M8W         Etobicoke
# 244      M8W         Etobicoke
# 245      M9W         Etobicoke
# 246      M1X       Scarborough
# 249      M4X  Downtown Toronto
# 250      M4X  Downtown Toronto
# 251      M5X  Downtown Toronto
# 252      M5X  Downtown Toronto
# 255      M8X         Etobicoke
# 256      M8X         Etobicoke
# 257      M8X         Etobicoke
# 262      M4Y  Downtown Toronto
# 265      M7Y      East Toronto
# 266      M8Y         Etobicoke
# 267      M8Y         Etobicoke
# 268      M8Y         Etobicoke
# 269      M8Y         Etobicoke
# 270      M8Y         Etobicoke
# 271      M8Y         Etobicoke
# 272      M8Y         Etobicoke
# 273      M8Y         Etobicoke
# 282      M8Z         Etobicoke
# 283      M8Z         Etobicoke
# 284      M8Z         Etobicoke
# 285      M8Z         Etobicoke
# 286      M8Z         Etobicoke
#
#                                          Neighbourhood  Latitude  Longitude
# 1                                            Parkwoods         0          1
# 2                                     Victoria Village         0          1
# 3                                         Harbourfront         0          1
# 4                                          Regent Park         0          1
# 5                                     Lawrence Heights         0          1
# 6                                       Lawrence Manor         0          1
# 7                                         Queen's Park         0          1
# 9                                     Islington Avenue         0          1
# 10                                               Rouge         0          1
# 11                                             Malvern         0          1
# 13                                     Don Mills North         0          1
# 14                                    Woodbine Gardens         0          1
# 15                                       Parkview Hill         0          1
# 16                                             Ryerson         0          1
# 17                                     Garden District         0          1
# 18                                           Glencairn         0          1
# 21                                          Cloverdale         0          1
# 22                                           Islington         0          1
# 23                                        Martin Grove         0          1
# 24                                    Princess Gardens         0          1
# 25                                     West Deane Park         0          1
# 26                                      Highland Creek         0          1
# 27                                          Rouge Hill         0          1
# 28                                          Port Union         0          1
# 30                                     Flemingdon Park         0          1
# 31                                     Don Mills South         0          1
# 32                                    Woodbine Heights         0          1
# 33                                      St. James Town         0          1
# 34                                  Humewood-Cedarvale         0          1
# 37                                   Bloordale Gardens         0          1
# 38                                            Eringate         0          1
